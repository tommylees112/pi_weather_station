# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.core.pylabtools import figsize
# %matplotlib inline

# %%
df = pd.read_csv('hackathon/2012_2018_30min.csv',index_col=0)
df.head()
# Out:
#                           TEMP  RAIN        WS
# 2012-01-09 00:00:00  11.402747   0.0  0.000000
# 2012-01-09 00:30:00  11.400000   0.0  0.001105
# 2012-01-09 01:00:00  11.423077   0.0  0.000000
# 2012-01-09 01:30:00  11.590608   0.0  0.000000
# 2012-01-09 02:00:00  11.606630   0.0  0.008840

# %%
figsize(12,8)
fig, axs = plt.subplots(3,1)

df.TEMP.plot(ax=axs[0], label="Temperature", title="Temperature (degC)")
df.RAIN.plot(ax=axs[1], label="Rainfall", title="Rainfall (mm)", color="#FF8214")
df.WS.plot(ax=axs[2], label="Wind Speed", title="Wind Speed (km/h)", color="#2CA02C")
plt.tight_layout()
